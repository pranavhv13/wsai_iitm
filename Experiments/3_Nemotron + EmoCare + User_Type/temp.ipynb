# %%
import pandas as pd

# %%
df = pd.read_csv("6_Responses.csv")

# %%
df.head()
# Out:
#                                                input  \
# 0  As a high school teacher, I enjoy teaching kid...
# 1  As a high school teacher, I enjoy teaching kid...
# 2  As a high school teacher, I enjoy teaching kid...
# 3  As a high school teacher, I enjoy teaching kid...
# 4  I'm worried that I'm not doing well in my grad...
#
#                                               output         user_type  \
# 0  It's great that you enjoy your profession and ...  Unconscious User
# 1  It's great that you enjoy your profession and ...     Avoidant User
# 2  It's great that you enjoy your profession and ...   Enthusiast User
# 3  It's great that you enjoy your profession and ...     Informed User
# 4  It's normal to feel uncertain at times, but I'...  Unconscious User
#
#                                               prompt  \
# 0  Instruction: "If you are a counsellor, please ...
# 1  Instruction: "If you are a counsellor, please ...
# ...

# %%
row = 0
print(df['output'][row],'\n---------')
print(df['prompt'][row],'\n---------')
print(df['gemini_response'][row],'\n---------')
print(df['cerebras_response'][row],'\n---------')
# Out:
# It's great that you enjoy your profession and can utilize your experience to help your child navigate through these challenging times. It is essential to maintain open communication with your child and provide guidance and support. Remember that this is a typical phase in their development, and you have the benefit of understanding what they are going through, which can be advantageous for both you and your child.
# ---------
# Instruction: "If you are a counsellor, please answer the questions based on the description of the patient."
#
# Persona: Marianus Kerketta is a 35‑year‑old early‑childhood teacher who blends folk traditions with modern pedagogy, loves cricket and photography, saves diligently while splurging on camera gear, and balances community service with personal ambition.
#
# ...
