# %%
import pandas as pd

# %%
df = pd.read_csv("4_user_types.csv")

# %%
df.head()
# Out:
#           User Type                                        Description
# 0  Unconscious User  The Unconscious User may not believe themselve...
# 1     Avoidant User  The Avoidant User has a largely negative view ...
# 2   Enthusiast User  The Enthusiast User has a strong positive view...
# 3     Informed User  The Informed User has a nuanced view on AI tec...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   User Type    4 non-null      str
#  1   Description  4 non-null      str
# dtypes: str(2)
# memory usage: 196.0 bytes

# %%
print(df['Description'][0],'\n---------')
print(df['Description'][1],'\n---------')
print(df['Description'][2],'\n---------')
print(df['Description'][3])
# Out:
# The Unconscious User may not believe themselves to be a user of AI powered tools at all. Often this group is uninterested in the technology itself and has a neutral view on it as a whole.
# ---------
# The Avoidant User has a largely negative view of AI powered tools and actively goes out of their way to avoid using them. They may see only negative aspects of AI tech and refute positive use cases.
# ---------
# The Enthusiast User has a strong positive view of AI technology. They may attempt to use AI at every given chance. This group may also overlook negative aspects in favor of the positives.
# ---------
# The Informed User has a nuanced view on AI tech. They understand that there are positives and negatives to using it. This group treats AI as a tool, and only use it when it would benefit a project.
