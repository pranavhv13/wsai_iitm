# %% [markdown]
# https://huggingface.co/datasets/nvidia/Nemotron-Personas-India

# %%
import pandas as pd

# %%
df = pd.read_csv("1_en_IN-00000-of-00011.csv")

# %%
df.head()
# Out:
#                                uuid  \
# 0  396f437fcf6a45e6b7f38f4fe5cf5e48
# 1  6e390f9220634682900a443817f0c25f
# 2  81ed007d28a447e3952a9359d6e9e528
# 3  cee655744c60442f9c04d665bc582863
# 4  8b96adc8927b415ca994337336dcc501
#
#                                 professional_persona  \
# 0  Bhai Shekh, a 23-year-old aspiring community f...
# 1  Meena Devi is a seasoned household matriarch w...
# 2  Esther Mary is a diligent abrasive slitting ma...
# 3  Omprakash Sharma, a senior excise officer with...
# 4  Parvati Devi, a seasoned household manager and...
#
#                                   linguistic_persona  \
# 0  Bhai Shekh, a fluent Gujarati speaker who pick...
# 1  Meena Devi speaks only Hindi, comfortably navi...
# 2  Esther Mary is a native Tamil speaker; they re...
# 3  Omprakash Sharma, a native Hindi speaker who c...
# 4  Parvati Devi, a fluent Hindi speaker who relie...
#
#                                       sports_persona  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 90910 entries, 0 to 90909
# Data columns (total 28 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   uuid                        90910 non-null  str
#  1   professional_persona        90910 non-null  str
#  2   linguistic_persona          90910 non-null  str
#  3   sports_persona              90910 non-null  str
#  4   arts_persona                90910 non-null  str
#  5   travel_persona              90910 non-null  str
#  6   culinary_persona            90910 non-null  str
#  7   persona                     90910 non-null  str
#  8   cultural_background         90910 non-null  str
#  9   linguistic_background       90910 non-null  str
#  10  skills_and_expertise        90910 non-null  str
#  11  skills_and_expertise_list   90910 non-null  str
#  12  hobbies_and_interests       90910 non-null  str
#  13  hobbies_and_interests_list  90910 non-null  str
# ...

# %%
row = 3
print(df['persona'][row],'\n---------')
print(df['cultural_background'][row],'\n---------')
# print(df['linguistic_background'][row],'\n---------')
# Out:
# Omprakash Sharma, a 38‑year‑old excise officer who blends analytical rigor with folk‑art passion, juggles tax audits and dhol beats, saves diligently yet splurges on cultural supplies, and tends to postpone dentist visits.
# ---------
# Omprakash Sharma hails from the rural outskirts of Bhagalpur in Bihar, a region where Angika culture, Magahi folklore, and the legacy of Bhagalpur silk weaving intersect. Growing up in a Sharma Brahmin family, he celebrates traditional Hindu festivals such as Chhath Puja, Diwali, and Holi, which blend religious rituals with community folk songs, dhol beats, and local fairs. The agrarian setting and tight-knit village network have given him a strong sense of community solidarity, respect for grassroots art forms, and an appreciation for the simple, collaborative lifestyle of rural Bihar.
# ---------
