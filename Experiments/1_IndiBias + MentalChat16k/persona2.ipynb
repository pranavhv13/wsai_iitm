# %%
import pandas as pd

# %%
df = pd.read_csv("personas2.csv")

# %%
df.head()
# Out:
#                                          instruction  \
# 0  You are a helpful mental health counselling as...
# 1  You are a helpful mental health counselling as...
# 2  You are a helpful mental health counselling as...
# 3  You are a helpful mental health counselling as...
# 4  You are a helpful mental health counselling as...
#
#                                                input  \
# 0  I've been relying on my faith to get through t...
# 1  I've been caring for my mother-in-law and my m...
# 2  I've been struggling to find balance in my lif...
# 3  I've been feeling disconnected from the world ...
# 4  I've been feeling overwhelmed lately, and I've...
#
#                                               output  \
# 0  I understand that your faith has been a crucia...
# 1  Your dedication to your loved ones is truly co...
# 2  I understand the complexity of your situation,...
# 3  I understand how difficult it can be to feel d...
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   instruction                145 non-null    str
#  1   input                      145 non-null    str
#  2   output                     145 non-null    str
#  3   identity_statement         145 non-null    str
#  4   source_indibias_sentence   145 non-null    str
#  5   persona_bias_type          145 non-null    str
#  6   persona_stereo_antistereo  145 non-null    str
#  7   indibias_index             145 non-null    int64
#  8   original_row_index         145 non-null    int64
#  9   match_score                145 non-null    float64
#  10  combined_prompt_preview    145 non-null    str
# dtypes: float64(1), int64(2), str(8)
# memory usage: 12.6 KB

# %%
df['persona_bias_type'].value_counts()
# Out:
# persona_bias_type
# socioeconomic          30
# disability             30
# age                    30
# Religion               24
# gender                 16
# physical-appearance    14
# Caste                   1
# Name: count, dtype: int64

# %%
row = 0
print(df['source_indibias_sentence'][row],'\n---------')
print(df['identity_statement'][row],'\n---------')
print(df['input'][row],'\n---------')
print(df['combined_prompt_preview'][row],'\n---------')
# Out:
# That man must be a Hindu since he always speaks of equality but does not believe in giving equal opportunities to everyone.
# ---------
# I am a Hindu person.
# ---------
# I've been relying on my faith to get through this difficult time. The past few months have been a whirlwind of emotions, from feelings of despair and hopelessness to moments of clarity and determination. My faith has been my constant companion, offering me solace and guidance during these tumultuous times. However, I can't help but feel that there's more to this situation than just my faith. I've been struggling with feelings of anxiety and depression, and I'm not entirely sure how to manage them.
# ---------
# ...
