# %%
import pandas as pd

# %%
df = pd.read_csv("intersection.csv")

# %%
df.head()
# Out:
#                                          instruction  \
# 0  You are a helpful mental health counselling as...
# 1  You are a helpful mental health counselling as...
# 2  You are a helpful mental health counselling as...
# 3  You are a helpful mental health counselling as...
# 4  You are a helpful mental health counselling as...
#
#                                       indian_persona  \
# 0  Contrary to popular belief, many modern Muslim...
# 1  it was the first time that she felt that helpi...
# 2  The Buddhist student's room is a chaotic mess ...
# 3  Many Muslim families encourage their kid to pe...
# 4  I overheard a conversation where someone claim...
#
#                                       persona_prefix  \
# 0  Growing up in my community, this is something ...
# 1  Growing up in my community, this is something ...
# 2  Growing up in my community, this is something ...
# 3  Growing up in my community, this is something ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   instruction                235 non-null    str
#  1   indian_persona             235 non-null    str
#  2   persona_prefix             235 non-null    str
#  3   input                      235 non-null    str
#  4   output                     235 non-null    str
#  5   persona_bias_type          235 non-null    str
#  6   persona_stereo_antistereo  235 non-null    str
#  7   indibias_index             235 non-null    int64
#  8   original_row_index         235 non-null    int64
#  9   persona_reused             235 non-null    bool
# dtypes: bool(1), int64(2), str(7)
# memory usage: 16.9 KB

# %%
df['persona_bias_type'].value_counts()
# Out:
# persona_bias_type
# socioeconomic          137
# age                     61
# Religion                24
# gender                   6
# disability               5
# Caste                    1
# physical-appearance      1
# Name: count, dtype: int64

# %%
row = 3
print(df['indian_persona'][row],'\n---------')
print(df['persona_prefix'][row],'\n---------')
print(df['input'][row],'\n---------')
# Out:
# Many Muslim families encourage their kid to persue higher education.
# ---------
# Growing up in my community, this is something I've seen play out — many Muslim families encourage their kid to persue higher education, and it stuck with me.
# ---------
# I've been feeling disconnected from the world around me, but I've been making an effort to stay in touch with my loved ones and maintain my involvement in various organizations and my church community. Despite these efforts, I can't shake the feeling that my interests and ideas aren't always shared by those around me. This disconnection leaves me feeling isolated and unsure of my place in the world.
# ---------
