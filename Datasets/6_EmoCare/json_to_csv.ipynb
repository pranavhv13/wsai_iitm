# %%
from datasets import load_dataset

dataset = load_dataset("json", data_files="Alexander_Street_shareGPT_2.0.json")

df = dataset["train"].to_pandas()

df.to_csv("dataset.csv", index=False)

print(df.shape)
df.head()
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# (8187, 3)
#                                          instruction  \
# 0  If you are a counsellor, please answer the que...
# 1  If you are a counsellor, please answer the que...
# 2  If you are a counsellor, please answer the que...
# 3  If you are a counsellor, please answer the que...
# 4  If you are a counsellor, please answer the que...
#
#                                                input  \
# 0  Lately, I've been feeling really disconnected ...
# 1  Lately, I've been feeling really stressed and ...
# 2  Lately, I've been feeling a bit off. I sometim...
# 3  Lately, I've been feeling a bit off. I've noti...
# 4  Lately, I've been feeling quite off. I have be...
#
#                                               output
# 0  Thank you for sharing your experience with me....
# 1  Thank you for sharing your experience with me....
# 2  I appreciate you sharing your concerns with me...
# ...

# %%
# !pip install datasets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 555.1/555.1 kB 286.5 kB/s  0:00:02eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 684.4/684.4 kB 476.8 kB/s  0:00:02eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 610.2 kB/s  0:00:07 eta 0:00:02
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.7/36.7 MB 1.1 MB/s  0:00:33m0:00:0100:020m
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0━━━━━━━━━━━━━━━━━━  3/14 [requests]
#     Uninstalling requests-2.31.0:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  3/14 [requests]
#       Successfully uninstalled requests-2.31.0━━━━━━━━━━━━━━━━  3/14 [requests]
#   Attempting uninstall: click╺━━━━━━━━━━━━━━━━━━━  7/14 [fsspec]ocess]
#     Found existing installation: click 8.3.1━━━━━━━━━━━━━━━━━━  7/14 [fsspec]
#     Uninstalling click-8.3.1:━━━━╸━━━━━━━━━━━━━━  9/14 [click]
#       Successfully uninstalled click-8.3.1m━━━━━━━━━━━━━━  9/14 [click]
# ...
