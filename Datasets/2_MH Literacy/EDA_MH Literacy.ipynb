# %% [markdown]
# - https://www.kaggle.com/datasets/mexwell/ai-driven-mental-health-literacy
# - https://psycharchives.org/en/item/2c9edde4-bc2f-44ca-b5bd-6e8438681e1f

# %%
import pandas as pd

# %%
df = pd.read_csv("Data - AI Driven MH Literacy.csv")

# %%
df.head()
# Out:
#    Age  Gender                      Educational.Qualification  \
# 0   19  Female                                           Bcom
# 1   20    Male                      Bcom computer application
# 2   19  Female  Pursuing a Bachelor's degree (BA/ BSc/ BTech)
# 3   20  Female  Pursuing a Bachelor's degree (BA/ BSc/ BTech)
# 4   19  Female  Pursuing a Bachelor's degree (BA/ BSc/ BTech)
#
#                         GPT_Use  pre.MHL_KMHP  pre.MHL_EBS  pre.MHL_FASHSB  \
# 0  Occasionally (once or twice)            28           12              13
# 1  Occasionally (once or twice)            29           11              14
# 2                Always (daily)            25           12              13
# 3                         Never            24           11              11
# 4                         Never            26            9              13
#
#    pre.MHL_SHS  pre.MHL_Total  pre.MHSAS  ...  post.SPANE_P  post.SPANE_N  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 34 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Age                        51 non-null     int64
#  1   Gender                     51 non-null     object
#  2   Educational.Qualification  51 non-null     object
#  3   GPT_Use                    51 non-null     object
#  4   pre.MHL_KMHP               51 non-null     int64
#  5   pre.MHL_EBS                51 non-null     int64
#  6   pre.MHL_FASHSB             51 non-null     int64
#  7   pre.MHL_SHS                51 non-null     int64
#  8   pre.MHL_Total              51 non-null     int64
#  9   pre.MHSAS                  51 non-null     float64
#  10  pre.STIG                   51 non-null     int64
#  11  pre.MHSES                  51 non-null     int64
#  12  pre.SPANE_P                51 non-null     int64
# ...

# %%
df['Educational.Qualification'].value_counts()
# Out:
# Educational.Qualification
# Pursuing a Bachelor's degree (BA/ BSc/ BTech)     30
# Completed a Master's course (MA/ MSc/ MTech)       6
# Completed a Bachelor's course (BA/ BSc/ BTech)     3
# Bcom                                               2
# Bcom computer application                          1
# B.com computer application                         1
# pursuing a Bachelor's Degree( B.Com CA)            1
# Pursuing a bachelors degree (Bcom)                 1
# Pursuing bcom computer application                 1
# Pursuing a Ph.D.                                   1
# BSc Psychology                                     1
# BCOM                                               1
# plus two                                           1
# Pursuing a bachelor's degree(b. Com)               1
# Name: count, dtype: int64

# %%
df['GPT_Use'].value_counts()
# Out:
# GPT_Use
# Never                           25
# Occasionally (once or twice)    13
# Sometimes (once a week)          8
# Always (daily)                   5
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#              Age  pre.MHL_KMHP  pre.MHL_EBS  pre.MHL_FASHSB  pre.MHL_SHS  \
# count  51.000000     51.000000    51.000000       51.000000    51.000000
# mean   19.823529     24.137255    12.411765       12.098039    16.529412
# std     1.807826      3.364637     1.675428        1.910549     1.724563
# min    18.000000     18.000000     9.000000        8.000000    11.000000
# 25%    19.000000     22.000000    12.000000       11.000000    15.000000
# 50%    19.000000     24.000000    12.000000       12.000000    17.000000
# 75%    20.000000     26.000000    13.500000       13.000000    17.500000
# max    25.000000     30.000000    15.000000       15.000000    20.000000
#
#        pre.MHL_Total  pre.MHSAS   pre.STIG  pre.MHSES  pre.SPANE_P  ...  \
# count      51.000000  51.000000  51.000000  51.000000    51.000000  ...
# mean       65.176471   5.808279  16.725490  35.392157    19.372549  ...
# std         5.931967   1.045408   5.862008  10.579373     3.918983  ...
# ...
