# %% [markdown]
# - https://huggingface.co/datasets/jastorj/MHQA
# - https://aikosh.indiaai.gov.in/home/datasets/details/bharatgen_mhqa_dataset.html

# %%
import pandas as pd

# %%
df = pd.read_csv("mhqa.csv")

# %%
df.head()
# Out:
#          id                           topic        type  \
# 0  28615767                      Depression  Diagnostic
# 1  17291595  Obsessive/Compulsive Disorders     Factoid
# 2  38514191  Obsessive/Compulsive Disorders  Prognostic
# 3  12787851  Obsessive/Compulsive Disorders  Preventive
# 4  24480417  Obsessive/Compulsive Disorders  Preventive
#
#                                             question  \
# 0  Which subgroup reported lower perceived social...
# 1  Which group of patients exhibited lower levels...
# 2  How does the overexpression of the Slc1a1 gene...
# 3  What treatment was shown to gradually decrease...
# 4  How does maternal obsessive-compulsive disorde...
#
#                                   option1                             option2  \
# 0  Recurrent depressive disorder patients           Anxiety disorder patients
# 1                        Healthy controls  Those with social anxiety disorder
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2475 entries, 0 to 2474
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2475 non-null   int64
#  1   topic                  2475 non-null   str
#  2   type                   2475 non-null   str
#  3   question               2475 non-null   str
#  4   option1                2475 non-null   str
#  5   option2                2475 non-null   str
#  6   option3                2475 non-null   str
#  7   option4                2475 non-null   str
#  8   correct_option         2475 non-null   str
#  9   correct_option_number  2475 non-null   int64
# dtypes: int64(2), str(8)
# memory usage: 193.5 KB

# %%
df['type'].value_counts()
# Out:
# type
# Diagnostic    879
# Preventive    714
# Prognostic    558
# Factoid       324
# Name: count, dtype: int64

# %%
df['topic'].value_counts()
# Out:
# topic
# Obsessive/Compulsive Disorders    637
# Depression                        617
# Trauma                            617
# Anxiety                           604
# Name: count, dtype: int64

# %%
df
# Out:
#             id                           topic        type  \
# 0     28615767                      Depression  Diagnostic
# 1     17291595  Obsessive/Compulsive Disorders     Factoid
# 2     38514191  Obsessive/Compulsive Disorders  Prognostic
# 3     12787851  Obsessive/Compulsive Disorders  Preventive
# 4     24480417  Obsessive/Compulsive Disorders  Preventive
# ...        ...                             ...         ...
# 2470  35666583  Obsessive/Compulsive Disorders  Diagnostic
# 2471  17174859  Obsessive/Compulsive Disorders  Diagnostic
# 2472  26843373  Obsessive/Compulsive Disorders  Preventive
# 2473  28615767                      Depression  Diagnostic
# 2474  33270336                          Trauma  Preventive
#
#                                                question  \
# 0     Which subgroup reported lower perceived social...
# 1     Which group of patients exhibited lower levels...
# 2     How does the overexpression of the Slc1a1 gene...
# ...
