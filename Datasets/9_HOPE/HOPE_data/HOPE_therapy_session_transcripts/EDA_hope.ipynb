# %% [markdown]
# - https://github.com/LCS2-IIITD/SPARTA_WSDM2022/tree/main#hope-dataset-access-request
# - https://dl.acm.org/doi/10.1145/3488560.3498509

# %%
import pandas as pd

# %%
df = pd.read_csv("27.csv")

# %%
df.head()
# Out:
#      ID Type                                          Utterance Dialog_Act
# 0  27_0    T  Okay, I want to thank you for your participati...         gc
# 1  27_1    P                                              yeah.         gc
# 2  27_2    T                                   Are you adopted?        ynq
# 3  27_3    P                                                No.        yna
# 4  27_4    T               All right. Are your parents married?        ynq

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          62 non-null     str
#  1   Type        62 non-null     str
#  2   Utterance   62 non-null     str
#  3   Dialog_Act  62 non-null     str
# dtypes: str(4)
# memory usage: 2.1 KB

# %%
df['Type'].value_counts()
# Out:
# Type
# T    31
# P    31
# Name: count, dtype: int64

# %%
df['Dialog_Act'].value_counts()
# Out:
# Dialog_Act
# irq    23
# id     23
# ynq     7
# ack     4
# yna     3
# gc      2
# Name: count, dtype: int64

# %%
row = 0
print(df['Type'][row],'\n---------')
print(df['Utterance'][row],'\n---------')
print(df['Dialog_Act'][row],'\n---------')
# Out:
# T
# ---------
# Okay, I want to thank you for your participation so far in this intake. But I want to move to another section of intake, specifically your family history if that's okay with you. So I'm going to be asking you various questions about your relatives. Okay,
# ---------
# gc
# ---------
